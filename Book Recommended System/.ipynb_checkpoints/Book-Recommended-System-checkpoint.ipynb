# %% [markdown]
# <h1 align="center"> Book-Recommended-System </h1>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
book = pd.read_csv("Books.csv")
rating = pd.read_csv("Ratings.csv")
user = pd.read_csv("Users.csv")
# Out:
# C:\Users\Harshad\AppData\Local\Temp\ipykernel_5840\3934456260.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   book = pd.read_csv("Books.csv")

# %%
print("Book shape: ",book.shape)
book.head(3)
# Out:
# Book shape:  (271360, 8)
#          ISBN            Book-Title           Book-Author Year-Of-Publication  \
# 0  0195153448   Classical Mythology    Mark P. O. Morford                2002
# 1  0002005018          Clara Callan  Richard Bruce Wright                2001
# 2  0060973129  Decision in Normandy          Carlo D'Este                1991
#
#                  Publisher                                        Image-URL-S  \
# 0  Oxford University Press  http://images.amazon.com/images/P/0195153448.0...
# 1    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
# 2          HarperPerennial  http://images.amazon.com/images/P/0060973129.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
#
#                                          Image-URL-L
# ...

# %%
print("Rating shape: ",rating.shape)
rating.head(3)
# Out:
# Rating shape:  (1149780, 3)
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0

# %%
print("User shape: ",user.shape)
user.head(3)
# Out:
# User shape:  (278858, 3)
#    User-ID                         Location   Age
# 0        1               nyc, new york, usa   NaN
# 1        2        stockton, california, usa  18.0
# 2        3  moscow, yukon territory, russia   NaN

# %%
print("Books:\n",book.isnull().sum())
print("Ratings:\n",rating.isnull().sum())
print("Users:\n",user.isnull().sum())
# Out:
# Books:
#  ISBN                   0
# Book-Title             0
# Book-Author            1
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64
# Ratings:
#  User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64
# Users:
#  User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
rwn = rating.merge(book,on="ISBN")

# %%
print(rwn.shape)
rwn.head(3)
# Out:
# (1031136, 10)
#    User-ID        ISBN  Book-Rating            Book-Title Book-Author  \
# 0   276725  034545104X            0  Flesh Tones: A Novel  M. J. Rose
# 1     2313  034545104X            5  Flesh Tones: A Novel  M. J. Rose
# 2     6543  034545104X            0  Flesh Tones: A Novel  M. J. Rose
#
#   Year-Of-Publication         Publisher  \
# 0                2002  Ballantine Books
# 1                2002  Ballantine Books
# 2                2002  Ballantine Books
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/034545104X.0...
# 1  http://images.amazon.com/images/P/034545104X.0...
# 2  http://images.amazon.com/images/P/034545104X.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/034545104X.0...
# 1  http://images.amazon.com/images/P/034545104X.0...
# 2  http://images.amazon.com/images/P/034545104X.0...
#
#                                          Image-URL-L
# ...

# %%
num_rating_df = rwn.groupby('Book-Title').count()['Book-Rating'].reset_index()

# %%
num_rating_df.rename(columns={'Book-Rating':'num_rating'},inplace=True)

# %%
print(num_rating_df.shape)
num_rating_df.head(5)
# Out:
# (241071, 2)
#                                           Book-Title  num_rating
# 0   A Light in the Storm: The Civil War Diary of ...           4
# 1                              Always Have Popsicles           1
# 2               Apple Magic (The Collector's series)           1
# 3   Ask Lily (Young Women of Faith: Lily Series, ...           1
# 4   Beyond IBM: Leadership Marketing and Finance ...           1

# %%
avg_rating_df = rwn.groupby('Book-Title').mean()['Book-Rating'].reset_index()
avg_rating_df.rename(columns={'Book-Rating':'avg_rating'},inplace=True)
print(avg_rating_df.shape)
avg_rating_df.head(5)
# Out:
# (241071, 2)
#                                           Book-Title  avg_rating
# 0   A Light in the Storm: The Civil War Diary of ...        2.25
# 1                              Always Have Popsicles        0.00
# 2               Apple Magic (The Collector's series)        0.00
# 3   Ask Lily (Young Women of Faith: Lily Series, ...        8.00
# 4   Beyond IBM: Leadership Marketing and Finance ...        0.00

# %%
pop_df = num_rating_df.merge(avg_rating_df,on="Book-Title")
pop_df.head(10)
# Out:
#                                           Book-Title  num_rating  avg_rating
# 0   A Light in the Storm: The Civil War Diary of ...           4        2.25
# 1                              Always Have Popsicles           1        0.00
# 2               Apple Magic (The Collector's series)           1        0.00
# 3   Ask Lily (Young Women of Faith: Lily Series, ...           1        8.00
# 4   Beyond IBM: Leadership Marketing and Finance ...           1        0.00
# 5   Clifford Visita El Hospital (Clifford El Gran...           1        0.00
# 6                                       Dark Justice           1       10.00
# 7                                           Deceived           2        0.00
# 8   Earth Prayers From around the World: 365 Pray...          10        5.00
# 9   Final Fantasy Anthology: Official Strategy Gu...           4        5.00

# %%
pop_df = pop_df[pop_df['num_rating']>=250].sort_values('avg_rating',ascending=False).head(50)

# %%
pop_df
# Out:
#                                                Book-Title  num_rating  \
# 80434   Harry Potter and the Prisoner of Azkaban (Book 3)         428
# 80422        Harry Potter and the Goblet of Fire (Book 4)         387
# 80441      Harry Potter and the Sorcerer's Stone (Book 1)         278
# 80426   Harry Potter and the Order of the Phoenix (Boo...         347
# 80414    Harry Potter and the Chamber of Secrets (Book 2)         556
# 191612  The Hobbit : The Enchanting Prelude to The Lor...         281
# 187377  The Fellowship of the Ring (The Lord of the Ri...         368
# 80445   Harry Potter and the Sorcerer's Stone (Harry P...         575
# 211384     The Two Towers (The Lord of the Rings, Part 2)         260
# 219741                              To Kill a Mockingbird         510
# 183573                                  The Da Vinci Code         898
# 187880                 The Five People You Meet in Heaven         430
# ...

# %%
pop_df.merge(book,on="Book-Title").drop_duplicates('Book-Title')
# Out:
#                                             Book-Title  num_rating  \
# 0    Harry Potter and the Prisoner of Azkaban (Book 3)         428
# 3         Harry Potter and the Goblet of Fire (Book 4)         387
# 5       Harry Potter and the Sorcerer's Stone (Book 1)         278
# 9    Harry Potter and the Order of the Phoenix (Boo...         347
# 13    Harry Potter and the Chamber of Secrets (Book 2)         556
# 16   The Hobbit : The Enchanting Prelude to The Lor...         281
# 17   The Fellowship of the Ring (The Lord of the Ri...         368
# 26   Harry Potter and the Sorcerer's Stone (Harry P...         575
# 28      The Two Towers (The Lord of the Rings, Part 2)         260
# 39                               To Kill a Mockingbird         510
# 47                                   The Da Vinci Code         898
# 53                  The Five People You Meet in Heaven         430
# 55                              The Catcher in the Rye         449
# ...

# %%
pop_df = pop_df.merge(book,on="Book-Title").drop_duplicates('Book-Title')[['Book-Title','Book-Author','Publisher','Image-URL-M','num_rating','avg_rating']]

# %%
pop_df.head()
# Out:
#                                            Book-Title    Book-Author  \
# 0   Harry Potter and the Prisoner of Azkaban (Book 3)  J. K. Rowling
# 3        Harry Potter and the Goblet of Fire (Book 4)  J. K. Rowling
# 5      Harry Potter and the Sorcerer's Stone (Book 1)  J. K. Rowling
# 9   Harry Potter and the Order of the Phoenix (Boo...  J. K. Rowling
# 13   Harry Potter and the Chamber of Secrets (Book 2)  J. K. Rowling
#
#      Publisher                                        Image-URL-M  num_rating  \
# 0   Scholastic  http://images.amazon.com/images/P/0439136350.0...         428
# 3   Scholastic  http://images.amazon.com/images/P/0439139597.0...         387
# 5   Scholastic  http://images.amazon.com/images/P/0590353403.0...         278
# 9   Scholastic  http://images.amazon.com/images/P/043935806X.0...         347
# 13  Scholastic  http://images.amazon.com/images/P/0439064872.0...         556
#
#     avg_rating
# 0     5.852804
# 3     5.824289
# 5     5.737410
# ...

# %%
pop_df['Image-URL-M'][0]
# Out:
# 'http://images.amazon.com/images/P/0439136350.01.MZZZZZZZ.jpg'

# %% [markdown]
# # Collaborative Filtering Based Recommender System

# %%
x = rwn.groupby('User-ID').count()['Book-Rating'] >200
plu = x[x].index

# %%
filter_rate = rwn[rwn['User-ID'].isin(plu)]

# %%
y = filter_rate.groupby('Book-Title').count()['Book-Rating']>=50
famous_book = y[y].index

# %%
final_rate = filter_rate[filter_rate['Book-Title'].isin(famous_book)]

# %%
pt = final_rate.pivot_table(index="Book-Title",columns="User-ID",values="Book-Rating")

# %%
pt.fillna(0,inplace=True)

# %%
pt
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
cosine_similarity(pt)
# Out:
# array([[1.        , 0.10255025, 0.01220856, ..., 0.12110367, 0.07347567,
#         0.04316046],
#        [0.10255025, 1.        , 0.2364573 , ..., 0.07446129, 0.16773875,
#         0.14263397],
#        [0.01220856, 0.2364573 , 1.        , ..., 0.04558758, 0.04938579,
#         0.10796119],
#        ...,
#        [0.12110367, 0.07446129, 0.04558758, ..., 1.        , 0.07085128,
#         0.0196177 ],
#        [0.07347567, 0.16773875, 0.04938579, ..., 0.07085128, 1.        ,
#         0.10602962],
#        [0.04316046, 0.14263397, 0.10796119, ..., 0.0196177 , 0.10602962,
#         1.        ]])

# %%
ss = cosine_similarity(pt)

# %%
ss
# Out:
# array([[1.        , 0.10255025, 0.01220856, ..., 0.12110367, 0.07347567,
#         0.04316046],
#        [0.10255025, 1.        , 0.2364573 , ..., 0.07446129, 0.16773875,
#         0.14263397],
#        [0.01220856, 0.2364573 , 1.        , ..., 0.04558758, 0.04938579,
#         0.10796119],
#        ...,
#        [0.12110367, 0.07446129, 0.04558758, ..., 1.        , 0.07085128,
#         0.0196177 ],
#        [0.07347567, 0.16773875, 0.04938579, ..., 0.07085128, 1.        ,
#         0.10602962],
#        [0.04316046, 0.14263397, 0.10796119, ..., 0.0196177 , 0.10602962,
#         1.        ]])

# %%
def recommend(book_name):
    index = np.where(pt.index==book_name)[0][0]
    similar_item = sorted(list(enumerate(ss[index])),key=lambda x:x[1],reverse=True)[1:6]
    for i in similar_item:
        print(pt.index[i[0]])

# %%
np.where(pt.index=='Year of Wonders')[0][0]
# Out:
# 701

# %%
sorted(list(enumerate(ss[0])),key=lambda x:x[1],reverse=True)[1:6]
# Out:
# [(47, 0.2702651417103732),
#  (545, 0.2639619371123497),
#  (82, 0.23669374347400993),
#  (634, 0.23299389358170394),
#  (551, 0.2262639743141286)]

# %%
recommend('1984')
# Out:
# Animal Farm
# The Handmaid's Tale
# Brave New World
# The Vampire Lestat (Vampire Chronicles, Book II)
# The Hours : A Novel

# %%
recommend('Brave New World')
# Out:
# 1984
# How to Be Good
# Naked
# Five Quarters of the Orange
# Love in the Time of Cholera (Penguin Great Books of the 20th Century)

# %%
import pickle
pickle.dump(pop_df,open('popular.pkl','wb'))

# %%
def recommend1(book_name):
    index = np.where(pt.index==book_name)[0][0]
    similar_item = sorted(list(enumerate(ss[index])),key=lambda x:x[1],reverse=True)[1:6]
    for i in similar_item:
        temp_df = book[book['Book-Title']==pt.index[i[0]]]
        print(temp_df.drop_duplicates('Book-Ttile')['Book-Author'])

# %%
recommend1('Harry Potter and the Goblet of Fire (Book 4)')
# Out:
#              ISBN                                         Book-Title  \
# 3839   0439136350  Harry Potter and the Prisoner of Azkaban (Book 3)
# 6330   0439136369  Harry Potter and the Prisoner of Azkaban (Book 3)
# 85245  0786222743  Harry Potter and the Prisoner of Azkaban (Book 3)
#
#          Book-Author Year-Of-Publication        Publisher  \
# 3839   J. K. Rowling                1999       Scholastic
# 6330   J. K. Rowling                2001       Scholastic
# 85245  J. K. Rowling                2000  Thorndike Press
#
#                                              Image-URL-S  \
# 3839   http://images.amazon.com/images/P/0439136350.0...
# 6330   http://images.amazon.com/images/P/0439136369.0...
# 85245  http://images.amazon.com/images/P/0786222743.0...
#
#                                              Image-URL-M  \
# 3839   http://images.amazon.com/images/P/0439136350.0...
# 6330   http://images.amazon.com/images/P/0439136369.0...
# ...
